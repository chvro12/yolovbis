# %% [markdown]
# # APKLOT + YOLOv8-seg (Colab)
#
# 1. Monter Google Drive (`/content/drive`).
# 2. Cloner ou copier le dépôt `Yolo` dans Drive.
# 3. `pip install -e ".[train_satellite]"` depuis la racine du projet.
# 4. Exécuter le quickstart (sous-ensemble **small** pour aller vite).
# 5. Sauvegarder `best.pt` et les dossiers `data/runs/...` vers Drive régulièrement.
#
# **Runtime** : GPU T4/L4 recommandé. Redémarrer le runtime après gros `pip install` si nécessaire.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import os, subprocess, sys
ROOT = '/content/drive/MyDrive/Yolo'  # adapter
os.chdir(ROOT)
subprocess.check_call([sys.executable, '-m', 'pip', 'install', '-e', '.[train_satellite]', '-q'])

# %%
import json, subprocess, sys
cmd = [
    sys.executable, '-m', 'parking_capacity.cli',
    'quickstart-apklot-yolo',
    '--dataset-subset', 'small',
    '--subset-max-images', '36',
    '--epochs', '20',
    '--imgsz', '640',
    '--run-name', 'colab_apklot_yolo',
]
subprocess.check_call(cmd)
print('OK — voir data/runs/colab_apklot_yolo/')

# %% [markdown]
# ## Visualiser les overlays
#
# Ouvrir dans Colab les fichiers PNG sous `data/runs/colab_apklot_yolo/sample_overlays/` ou `val_predictions/`.
